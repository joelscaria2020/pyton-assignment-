# %%
import pandas as pd

# %%
from google.colab import files
upload =files.upload()
# Out:
#      <input type="file" id="files-ecfc4f40-9fbd-4d47-b180-46d1ac4167e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ecfc4f40-9fbd-4d47-b180-46d1ac4167e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Student Performance.csv to Student Performance.csv

# %%
import pandas as pd

# %%
stud = pd.read_csv ("Student Performance.csv")
stud.head()
# Out:
#    gender race/ethnicity  ... reading score writing score
# 0  female        group B  ...            72            74
# 1  female        group C  ...            90            88
# 2  female        group B  ...            95            93
# 3    male        group A  ...            57            44
# 4    male        group C  ...            78            75
#
# [5 rows x 8 columns]

# %%
stud.plot.scatter( "math score", "reading score" ,figsize=(9,3))

# %%
stud.plot.scatter( "parental level of education", "reading score", figsize=(9,3))

# %%
stud.plot.scatter ("test preparation course", "reading score", figsize=(9,3))

# %%
import seaborn as sns 
sns.countplot(stud['parental level of education'])
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
